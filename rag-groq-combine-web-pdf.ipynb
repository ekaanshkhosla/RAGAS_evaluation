# %%
pip install -q ragas
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.1 which is incompatible.
# jupyterlab 4.2.4 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.2 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.4 requires shapely<2.1,>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# pointpats 2.5.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# spaghetti 1.7.6 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ...

# %%
import os
os.environ['OPENAI_API_KEY'] ="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"

# %%
from datasets import Dataset 
from ragas.metrics import faithfulness, answer_correctness
from ragas import evaluate

data_samples = {
    'question': ['What is France capital?', 'What is India capital?'],
    'answer': ['France capital is Delhi', 'India capital is spain'],
    'ground_truth': ['France capital is Paris.', 'India capital is Delhi']
}
dataset = Dataset.from_dict(data_samples)
score = evaluate(dataset,metrics=[answer_correctness])
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
#                   question                   answer              ground_truth  \
# 0  What is France capital?  France capital is Delhi  France capital is Paris.
# 1   What is India capital?   India capital is spain    India capital is Delhi
#
#    answer_correctness
# 0            0.229625
# 1            0.230488

# %%
Questions = [
    'Will the language of instruction of my Bachelor’s degree suffice to demonstrate my proficiency in English for admission in Msc Data Science at FAU Erlangen?',
    'Is an APS certificate mandatory for Indian students during the application process?',
    'How long does it typically take to receive a decision regarding my application to the MSc Data Science program?',
    'Am I eligible to apply for the study course program with a degree from a technical university or a university of applied sciences?',
    'Can I apply for the study course program with a degree obtained through a dual study program?',
    'What could be the reasons for receiving a rejection for my application?',
    'Is it possible to defer my admission to a future semester?',
    'Where can I find accommodation while studying at FAU?',
    'Can I switch my major subject after being admitted?',
    'Is it allowed to combine modules from different application subjects?',
    'How can I transfer ECTS credits from one module group to another?',
    'Can modules from my major subject count towards my minor subject requirements?',
    'Can my werkstudent experience be used to earn ECTS as a technical qualification?',
    'Can I participate in an examination without prior registration?',
    'How do I register for a module’s examination in Campo within the correct specialisation area?',
    'If I fail an examination on the first attempt, is it mandatory to attend the next attempt?',
    'Is it possible to withdraw from an examination after registering?',
    'What should I do if I cannot attend an examination due to illness?',
    'What are the consequences of failing an examination three times?',
    'Can I retake a completed module to improve my grades?',
    'Is it possible to improve my grades by completing additional modules?',
    'How many ECTS credits are required before I can start writing my Master’s thesis?',
    'How can I find a topic for my Master’s thesis?',
    'Who is eligible to supervise my Master’s thesis?',
    'Can my Master’s thesis supervisor be from a different department?',
    'Is it possible to complete my Master’s thesis while working in a company?',
    'Is it necessary to have a university supervisor for a company-based thesis?',
    'What is the process for registering my Master’s thesis?',
    'What steps should I take after completing my Master’s thesis?',
    
    'What are the admission requirements of M.Sc. Data Science at FAU Erlangen?',
    'How can I apply for M.Sc. Data Science at FAU Erlangen?',
    'Is accommodation available at FAU Erlangen?',
    'How can I finance my studies at FAU Erlangen?',
    'What are the next steps if I get an admission at FAU Erlangen?',
    'What is the duration of M.Sc. Data Science degree program at FAU Erlangen?',
    'What is the teaching language of M.Sc. Data Science at FAU Erlangen?',
    'What is the structure of M.Sc. Data Science at FAU Erlangen?',
    'Is German required for M.Sc. Data Science at FAU Erlangen?',
    'What is the duration of B.Sc. Data Science degree program at FAU Erlangen?',
    'What is the teaching language of B.Sc. Data Science at FAU Erlangen?',
    'What is the structure of B.Sc. Data Science FAU Erlangen?',
    'What are the admission requirements of B.Sc. Data Science FAU Erlangen?'
]

# %%
Ground_truth = [
    'Yes, if your Bachelor’s degree was taught in English then you can apply with a certificate from your university stating the the language of instruction for your degree has been in English.',
    'The APS certificate is mandatory for the application procedure at FAU as well as for applying for the study visa.',
    'Due to a high number of international applications each semester the admission committee requires a lot of time to evaluate all application documents. Usually, you should receive a decision notification about 4 weeks after the application deadline. If you have not received any answer yet after 4 weeks, please be patient. If you have not received any answer to your application after 8 weeks, we recommend you politely ask the Master’s Office about the current state of your application.',
    'Yes, any degree from a technical university or university of applied sciences will be treated equally with a degree from a university.',
    'Yes, your degree from a dual study programme will be treated equally with a degree from a university if it consists of at least 180 ECTS being completed at a university.',
    'We are sorry that your application did not lead to admission to this study course programme. In many cases the reason for rejection is that students have not the required qualification for this study course programme, i.e., a completed B.Sc. degree in Mathematics, Industrial Mathematics, Mathematical Economy, Computer Science, Data Science, or Physics from FAU or another equivalent domestic or international degree that is not significantly different with regard to the competence profile taught in the respective degree.',
    'Yes, it is possible to defer your admission. Just re-apply for the next semester and upload the current admission letter you received. You will be granted admission provided that there are no significant changes to the regulations and selection criteria.',
    'FAU itself and its staff cannot help you with finding suitable accommodation for your studies in general, but please start by reading the following website with helpful links: https://www.fau.eu/education/student-life/accommodation-2/. We are aware that it is difficult to find a nice flat as the region around Erlangen and Nürnberg is very popular for living and thus costs for accommodation are very high. For this reason we recommend sharing a flat with other students, e.g., by taking one of the offers on the following websites: https://www.wg-gesucht.de/wg-zimmer-in-Erlangen.34.0.1.0.html, https://www.immobilienscout24.de/Suche/de/bayern/erlangen/wg-zimmer, https://www.wg-suche.de/wg-zimmer/deutschland-bayern-erlangen. Additionally, you can join dedicated groups for accommodations in Erlangen in social networks, e.g., on Facebook. In case you have trouble finding a suitable accommodation you can also send an email to accommodation@fau.de.',
    'Yes, you can change your major at any time without any formal process. You should discuss changes of your study plan agreement with your mentor.',
    'Yes, you are free to choose the modules from any of the application subjects and combine them.',
    'Please send a polite email to the examination office and ask for the transfer of credits. This should best be done near the end of your studies to collect all changes necessary and hence minimize the work effort for the examination office.',
    'No, modules for your minor subject must be chosen from specialisations other than your major subject.',
    'You can use your working experience as a technical qualification if you work longer than 4 weeks in a company and if your tasks are related to Data Science. The examination committee has to agree to your work description in order to be usable as a module. Usually, you will have to hand in a short report (~10 pages) about your working tasks.',
    'No, you can only participate in an examination if you have previously registered for it on the Campo portal within the exam registration period. You can find details on the current exam registration periods at https://www.fau.de/education/beratungs-und-servicestellen/pruefungsaemter/pruefungsamt-naturwissenschaftliche-fakultaet/. Please note that if you miss the exam registration period the examination office will not register you for examinations subsequently.',
    'Indeed, there exist modules in this study course programme that can be counted for two different module groups, e.g., two different specialization areas. Currently, the Campo system pre-selects one of these module groups, making the other one inactive. If you cannot find the register button in the correct module group and have not registered for the module yet, please proceed as follows: 1. Please log in to Campo and click Home → My studies → Study planner with module plan. 2. Use the view options in the top to show all examinations, hide all lectures and expand all modules. 3. Use your browser’s search function to search for your module. Make sure you find the module name in the desired module group. 4. If you click on the title of the module in the desired module group as shown in the image below, the Register button becomes available and you should be able to register. 5. If this does not work and the module is shown in gray, then there is a problem in the system, which cannot be solved by you. In this case, please send an email to studiengangskoordination-datascience@math.fau.de.',
    'Yes, you will automatically be registered for the next attempt by the examination office and can only step back from it with a medical certificate verifying that you are unable to attend the examination. This certificate has to be sent as original via post mail to the examination office. Not attending the examination will be counted as a failed attempt.',
    'If you have not yet attended this examination before, you can step back from it without further reasons until three working days before the examination. Use the button Deregister in the Campo system for this. If you have attempted this examination before, you can only step back from it with a medical certificate verifying that you are unable to attend the examination. Not attending the examination will be counted as a failed attempt.',
    'In this case, please submit a notification of illness to the examination office by filling out the following form: https://www.fau.de/files/2015/08/Krankmeldung.pdf within three days. Also submit a medical certificate about your illness in original to the examination office. If you don’t submit these two mandatory documents in the specified time and don’t attend the examination it will be counted as a failed attempt.',
    'After three unsuccessful attempts for an examination, the module will be counted as not being passed. This state cannot be changed any more and you cannot pass this module in the future any more. If the module is an elective mandatory module, also denoted as core elective module in Campo, you can simply choose another module and continue your studies. If the module is a core module of your study course (Mathematics of Learning, Selected Topics of Mathematics of Learning, or Deep Learning) you cannot continue your studies in this study course programme at FAU unfortunately.',
    'No, you cannot repeat a module that you have passed previously. The only way to improve your certificate grades is by completing additional modules with a better grade within the same module group.',
    'You can improve your overall grade only before you reach the mandatory 120 ECTS of the study course. Once you have reached the required amount of ECTS in all module groups (including Master seminar and Master’s thesis) you will be exmatriculated automatically at the end of the current semester.',
    'It is highly recommended that you complete 75 ECTS of your study curriculum and subsequently choose a Master’s seminar topic. You should have completed all core modules and all modules of your major subject first. Afterwards, you can start writing your Master’s thesis. The topic of your Master’s thesis should ideally fit the chosen specialisation and the topic of the Master’s seminar, following §54 of the examination regulations ("Mentoring") and your individual study agreement.',
    'The easiest way to find a topic for your Master’s thesis is to attend a Master’s seminar near the end of your studies and work on a topic that you are interested in. In many cases, your supervisor in the Master’s seminar can suggest you a topic for your Master’s thesis that directly builds upon the subject of your Master’s seminar. Since you have already invested time in literature research for this topic, this will save you a lot of work effort for your Master’s thesis. Alternatively, you can also search for a Master’s thesis topic independently of your Master’s seminar. For this, you should contact the chairs at FAU that perform research in the area of Data Science in which you are interested and politely ask for the possibility to write a Master’s thesis at this chair.',
    'To start your Master’s thesis, you need an official supervisor from FAU first. There are certain requirements that have to be met by your supervisor. The person has to be a professor or at least have a finished habilitation (recognizable by the title "Dr. habil." or "PD") and needs to have a membership in one of the following departments: Department of Data Science, Department of Mathematics, Department of Computer Science, or Department of Artificial Intelligence in Biomedical Engineering (AIBE). Professors who are a secondary member in one of these listed departments can also supervise your thesis. If you are not certain if they fulfill these requirements, please ask the person directly. Your official supervisor is also the first examiner of your thesis and should propose you a second examiner for your thesis that has to fulfill the same requirements, but can be from any department at FAU. Your Master’s thesis can additionally be supervised or guided by other FAU staff, e.g., PhD students, who are working in the subject of your Master’s thesis. However, they cannot be your official supervisors.',
    'In a few cases, the examination committee might allow for exceptions if the proposed topic suits your study programme well and the proposed supervisor agrees to meet the requirements of the examination committee. In case you would like to write your thesis with a professor who is not a member of any of the above-mentioned departments, please ask the admission committee about permission in advance. Please also make sure that the second examiner of your Master’s thesis belongs to one of the four departments mentioned above.',
    'Yes, it is possible to carry out the Master’s thesis in a company. However, as previously mentioned, the thesis topic must align with the research conducted at the four departments mentioned above. Consequently, it is necessary to contact professors from these departments to serve as your official supervisor at the university.',
    'Absolutely, it is mandatory to have a supervisor from the university for a company-based thesis. The supervisor together with a second examiner at FAU are responsible for grading your Master’s thesis. This cannot be done by externals at a company.',
    'Thesis registration requires the completion of a form, which can be obtained from the following location: https://www.math-datascience.nat.fau.de/files/2023/12/Anmeldung_Masters-Thesis_LE_Mathematik_und_DataScience_englisch.pdf. It is essential to discuss the thesis registration with your respective professor before sending the form. Please fill out the form with the assistance of your supervisor and submit it to the examinations office via post mail to petra.frosch@fau.de. Once the registration form is submitted and your thesis is registered, you will have a total of six months to submit your final Master’s thesis.',
    'When you have finished your Master’s thesis and your supervisor is content with the result, you have to print your Master’s thesis twice and send it to the examination office to complete the process. If you developed your own code for your Master’s thesis, please give your supervisor a copy of this code on a USB stick. The two examiners will get the hard copies of your Master’s thesis and will review it for the final grade.',
    
    
    'A completed B.Sc. degree in Mathematics, Industrial Mathematics, Mathematical Economy, Computer Science, Data Science, or Physics from FAU or another equivalent domestic or international degree that is not significantly different with regard to the competence profile taught in the respective degree. Please note that your competence profile cannot be evaluated in advance, but only by the admission committee after completing the application process (described below). A Grade Point Average (GPA) of 2.5 or better with respect to the German grading system. Candidates with an admissible degree (described above) and a GPA between 2.6 and 2.8 are invited for a short online interview in which their knowledge in calculus, linear algebra, algorithms and data structures is evaluated. An online tool for converting grades to the German grading system using the Bavarian formula can be found here. English proficiency at level B2 CEFR (vantage or upper intermediate, not be older than 2 years) or six years of English classes at a German secondary school (Gymnasium). Applicants who have completed their university entrance qualifications or their first degree in English are not required to provide proof of proficiency in English. A list of accepted language proficiency certificates can be found here.',
    'The application for M.Sc. Data Science is performed online: Registration for the winter intake is possible between 15th February and 31st May and for the summer intake between 15th September and 30th November. You can find the exact dates for the current intake periods on https://www.fau.eu/education/application-and-enrolment/applying-for-masters-degree-programmes/#bewerbungszeitraum Register online using the page www.campo.fau.eu Note: Applicants who have not yet an „ IdM Account “ have to register at IdM first (on www.campo.fau.eu ). IdM stands for Identity Management of FAU. Then, using your IdM account, you can set up your online application. For further questions concerning the process of application please contact our Master’s Office: zuv-masterbuero@fau.de For further questions on the online application portal please send an email to: campo@fau.de',
    'FAU Erlangen-Nürnberg is not able to offer accommodation. The University does not operate any student accommodation and is not allowed to act as an estate agent. However, information on finding accommodation is provided here.',
    'Financing your studies and costs: There is only one semester fee / student services fee for each student, no matter which country of origin, that has to be paid every semester. Further information regarding costs of studying such as living or food is provided here. FAU Erlangen-Nürnberg does not have any funding available to support international students with their living costs. For this reason, international students usually receive scholarships from their home country or use their own funds to finance their studies. You might search for scholarships at the DAAD website here.',
    'After you receive your admission letter you have to enrol for the next semester by sending your certified documents via postal service to the Student Records Office. The enrolment fee should be transferred several days before, especially if transferred from abroad. In this case we recommend to calculate with at least two weeks. You can find further information on enrolment and first steps afterwards here. After enrolment you are given access to online teaching resources and several other important platforms. Start by creating a user account at FAU (IdM account) and get familiar with the two online platforms „StudOn“ and „Campo„, which will help you to plan and manage your courses.',
    '4 semesters or 2 years',
    'Completely in English',
    'The M.Sc. Data Science degree programme offers the following specialization areas: Data-based optimization Mathematical theory / Fundamentals of data science (taught in German) Databases and knowledge representation Machine learning / Artificial intelligence Simulation and numerics Mathematical statistical data analysis A student has to select one specialization area as major field of study in which modules of in total 30 ECTS have to be completed. All other specialization areas form the minor field of study in which modules of in total 20 ECTS have to be completed. Additionally, there are three core modules of in total 15 ECTS that are mandatory for all students of this degree programme. This is complemented by technical qualification modules of in total 5 ECTS. Every student has to complete modules of in total 15 ECTS from the following application subjects: Artificial intelligence in biomedical imaging Chemistry Digital humanities Geography Geosciences International information systems Medical data science Material Science Physics The degree programme is finalized by a Master’s seminar (5 ECTS) that should lead to writing a Master’s thesis (30 ECTS) in the field of Data Science.',
    'No, but for everyday life and for internships and working student jobs, we recommend solid knowledge (B1) of German, but a certificate is not necessary for the application.',
    '6 semesters or 3 years',
    'Completely in German',
    'The bachelor’s degree program “Data Science” can be divided into the following consecutive levels: 1st-2nd semester: Fundamentals In the first year you will learn the basics of analysis, linear algebra, algorithms and data structures, modeling, and programming. 3rd-4th semester: Advanced In the second year you build on the basics you have learned and get to know many important mathematical tools from the areas of numerics, optimization, and stochastics. At the same time you deal with logic, information visualization, and knowledge extraction from databases. 5th-6th semester: Consolidation and application In the third year of study, you will listen to freely selectable in-depth lectures within mathematics and computer science, which specifically fit the course of study “Data Science”. Possible areas of specialization are Statistical Data Analysis, Data-Oriented Optimization, Mathematical Theory of Data Science, Knowledge Representation, Artificial Intelligence, as well as Simulation and Numerics. Here you can adapt your focus to your own interests, i.e. focus more on theory or practice. At the same time, you will apply the knowledge you have acquired in the first two years in lectures of your application subject. 6th semester: Bachelor thesis In the sixth semester you will write your bachelor thesis in your chosen field of specialization. In parallel to the above-mentioned study phases, you will continuously attend lectures from the core area of “Data Science”, such as mathematical data analysis and modeling, machine learning, or advanced design and programming.',
    'Admission requirements (first semester) No Admissions Restrictions Application deadline winter semester 30.09. Language skills General language skills For enrollment in the B.Sc. Data Science program, very good German language skills are generally required. More detailed information on the accepted language certificates for international students can be found at https://www.fau.de/education/international/aus-dem-ausland-an-die-fau/bewerbung-und-einschreibung-fuer-internationale-bewerberinnen-und-bewerber/deutschkenntnisse-und-sprachzertifikate/. Details and notes The application deadline for the winter semester for international applicants is July 15th. Applications have to be submitted via the campus management portal campo.fau.de In addition to the general qualification for university entrance (Abitur), there are other access options for studying at FAU.'
]

# %%
# Rewriting the data_samples to ensure there are no syntax errors

data_samples = {
    
    'question': Questions,
    
    "answer": ['Yes, if your Bachelor’s degree was taught in English, then you can apply with a certificate from your university stating that the language of instruction for your degree has been in English.',
 'The APS certificate is mandatory for the application procedure at FAU as well as for applying for the study visa.',
 'Typically, you should receive a decision notification about 4 weeks after the application deadline. If you have not received any answer yet after 4 weeks, please be patient. If you have not received any answer to your application after 8 weeks, it is recommended that you politely ask the Master’s Office about the current state of your application.',
 'Yes, any degree from a technical university or university of applied sciences will be treated equally with a degree from a university.',
 'Yes, your degree from a dual study program will be treated equally with a degree from a university if it consists of at least 180 ECTS being completed at a university.',
 'The reasons for receiving a rejection for your application may include that you do not have the required qualification for the study course program, i.e., a completed B.Sc. degree in Mathematics, Industrial Mathematics, Mathematical Economy, Computer Science, Data Science, or Physics from FAU or another equivalent domestic or international degree that is not significantly different with regard to the competence profile taught in the respective degree.',
 'According to the provided text snippet, yes, it is possible to defer your admission to a future semester. You just need to re-apply for the next semester and upload the current admission letter you received. You will be granted admission provided that there are no changes.',
 'According to the provided text, you can find accommodation while studying at FAU by:\n\n1. Reading the following website with helpful links: https://www.fau.eu/education/student-life/accommodation-2/\n2. Sharing a flat with other students, and you can find offers on the following websites:\n   - https://www.wg-gesucht.de/wg-zimmer-in-Erlangen.34.0.1.0.html\n   - https://www.immobilienscout24.de/Suche/de/bayern/erlangen/wg-zimmer\n   - https://www.wg-suche.de/wg-zimmer/deutschland-bayern-erlangen\n3. Joining dedicated groups for accommodation in Erlangen on social networks, such as Facebook.\n4. Sending an email to accommodation@fau.de if you have trouble finding a suitable accommodation.\n\nPlease note that FAU itself and its staff cannot help you with finding accommodation.',
 'Yes, you can change your major at any time without any formal process. You should discuss changes of your study plan agreement with your mentor.',
 'Yes, you are free to choose the modules from any of the application subjects and combine them.',
 'To transfer ECTS credits from one module group to another, you should send a polite email to the examination office and ask for the transfer of credits. It is recommended to do this near the end of your studies to collect all changes necessary and minimize the work effort for the examination office.',
 'No, modules for your minor subject must be chosen from specialisations other than your major subject.',
 'Yes, you can use your werkstudent experience to earn ECTS as a technical qualification if you work longer than 4 weeks in a company and if your tasks are related to Data Science. The examination committee has to agree to your work description in order to be usable as a module. Usually, you will have to hand in a short report (~ 10 pages) about your working tasks.',
 'No, you can only participate in an examination if you have previously registered for it on the Campo portal within the exam registration period.',
 "To register for a module's examination in Campo within the correct specialisation area, please follow these steps:\n\n1. Log in to Campo and click Home → My studies → Study planner with module plan.\n2. Use the view options in the top to show all examinations, hide all lectures, and expand all modules.\n3. Use your browser's search function to search for your module. Make sure you find the module name in the desired module group.\n4. If you click on the title of the module in the desired module group as shown in the image, the Register button becomes available, and you should be able to register.\n5. If this does not work and the module is shown in gray, there is a problem in the system, which cannot be solved by you. In this case, please send an email to studiengangskoordination-datascience@math.fau.de.",
 'Yes, you will automatically be registered for the next attempt by the examination office and can only step back from it with a medical certificate verifying that you are unable to attend the examination.',
 'Yes, it is possible to withdraw from an examination after registering. According to the provided text, students can withdraw from an examination without stating reasons up until the end of the third working day before the examination date. However, if a student has attempted the examination before, they can only withdraw with a medical certificate verifying that they are unable to attend the examination.',
 'If you cannot attend an examination due to illness, you should submit a notification of illness to the examination office by filling out the form (https://www.fau.de/files/2015/08/Krankmeldung.pdf) within three days. Additionally, you should submit a medical certificate about your illness in original to the examination office.',
 'According to Section 26 of the provided text, if a student fails an examination three times, the module will be counted as not being passed. This state cannot be changed, and the student cannot pass this module in the future. If the module is an elective mandatory module, the student can choose another module and continue their studies. However, if the module is a core module of their study course, the student cannot continue their studies in this study course program at FAU.',
 'No, you cannot repeat a module that you have passed previously. The only way to improve your certificate grades is by completing additional modules with a better grade within the same module group.',
 'You can improve your overall grade only before you reach the mandatory 120 ECTS of the study course. Once you reached the required amount of ECTS in all module groups (including Master seminar and Master’s thesis) you will be exmatriculated automatically at the end of the current semester.',
 "It is highly recommended that you complete 75 ECTS of your study curriculum before starting your Master's thesis.",
 "The easiest way to find a topic for your Master's thesis is to attend a Master's seminar near the end of your studies and work on a topic that you are interested in. In many cases, your supervisor in the Master's seminar can suggest a topic for your Master's thesis that directly builds upon the subject of your Master's seminar. This can save you a lot of work effort for your Master's thesis as you have already invested time in literature research for this topic. Alternatively, you can also search for a Master's thesis topic independently of your Master's seminar by contacting the chairs at FAU that perform research in the area of Data Science you are interested in and politely asking for the possibility to write a Master's thesis at this chair.",
 'According to the provided documents, the eligibility to supervise a Master\'s thesis is governed by the relevant degree program and examination regulations. However, it is stated that university lecturers in principal employment at the Department of Mathematics or the Department of Data Science for the degree program in question are generally entitled to assign Master\'s theses. This includes professors who are a secondary member in one of these listed departments.\n\nMore specifically, the requirements for an official supervisor are:\n\n- The person must be a professor or have a finished habilitation (recognizable by the title "Dr. habil." or "PD").\n- They need to have a membership in one of the following departments:\n  • Department of Data Science\n  • Department of Mathematics\n  • Department of Computer Science\n  • Department of Artificial Intelligence in Biomedical Engineering (AIBE)\n\nIn exceptional cases, the examination committee may allow for exceptions if the proposed topic suits the student\'s study program well and the proposed supervisor agrees to meet the requirements of the examination committee.',
 'According to the provided text, in a few cases, the examination committee might allow for exceptions if the proposed topic suits your study programme well and the proposed supervisor agrees to meet the requirements of the examination committee.',
 'Yes, it is possible to complete your Master\'s thesis while working in a company. According to the text, "Yes, it is possible to carry out the Master\'s thesis in a company. However, as previously mentioned, the thesis topic must align with the research conducted at the four departments mentioned above. Consequently, it is necessary to contact professors from these departments to serve as your official supervisor at the university."',
 'Yes, it is mandatory to have a university supervisor for a company-based thesis.',
 "To register your Master's thesis, you need to complete a form, which can be obtained from the following location: https://www.math-datascience.nat.fau.de/files/2023/12/Anmeldung_Masters-Thesis_LE_Mathematik_und_DataScience_englisch.pdf. It is essential to discuss the thesis registration with your respective professor before sending the form. Please fill out the form with the assistance of your supervisor and submit it to the examinations office via post mail to petra.frosch@fau.de.",
 'When you have finished your Master’s thesis and your supervisor is content with the result, you have to print your Master’s thesis twice and send it to the examination office to complete the process. If you developed own code for your Master’s thesis, please give your supervisor a copy of this code on a USB stick. The two examinators will get the hard-copies of your Master’s thesis and will review it for the final grade.',
 "The admission requirements for M.Sc. Data Science at FAU Erlangen include:\n\n1. A completed B.Sc. degree in Mathematics, Industrial Mathematics, Mathematical Economy, Computer Science, Data Science, or Physics from FAU or another equivalent domestic or international degree that is not significantly different with regard to the competence profile taught in the respective degree.\n2. A Grade Point Average (GPA) of 2.5 or better with respect to the German grading system. Candidates with an admissible degree and a GPA between 2.6 and 2.8 are invited for a short online interview in which their knowledge in calculus, linear algebra, algorithms, and data structures is evaluated.\n3. English proficiency at level B2 CEFR (vantage or upper intermediate) or six years of English classes at a German secondary school (Gymnasium). Applicants who have completed their university entrance qualifications or their first degree in English are not required to provide proof of proficiency in English.\n\nNote: The admission requirements may be subject to change, and it's always best to check the official website of FAU Erlangen or contact the university's admission office for the most up-to-date information.",
 'To apply for the M.Sc. Data Science program at FAU Erlangen, you need to register online through the website www.campo.fau.eu. If you don\'t have an "IdM Account" yet, you need to register for one first. Then, you can set up your online application using your IdM account. \n\nAdditionally, you can find the exact dates for the current intake periods on the website https://www.fau.eu/education/application-and-enrolment/applying-for-masters-degree-programmes/#bewerbungszeitraum. \n\nIf you have any further questions concerning the application process, you can contact the Master\'s Office at zuv-masterbuero@fau.de. For questions about the online application portal, you can send an email to campo@fau.de.',
 'No, FAU Erlangen-Nürnberg is not able to offer accommodation. However, information on finding accommodation is provided on their website.',
 'According to the provided text, there is only one semester fee/student services fee for each student at FAU Erlangen-Nürnberg, regardless of their country of origin. This fee must be paid every semester. However, the university does not have any funding available to support international students with their living costs.\n\nInternational students usually receive scholarships from their home country or use their own funds to finance their studies. You might search for scholarships at the DAAD website.',
 'If you receive an admission letter from FAU Erlangen, the next steps would be to enroll for the next semester by sending your certified documents via postal service to the Student Records Office. You should also transfer the enrolment fee several days in advance, especially if you are transferring from abroad. It is recommended to calculate with at least two weeks for the transfer.',
 'The duration of the M.Sc. Data Science degree program at FAU Erlangen is 4 semesters.',
 'The teaching language of the M.Sc. Data Science program at FAU Erlangen-Nürnberg is completely in English.',
 "The M.Sc. Data Science degree program at FAU Erlangen has the following structure:\n\n* The program offers several specialization areas, including Data-based optimization, Mathematical theory / Fundamentals of data science, Databases and knowledge representation, Machine learning / Artificial intelligence, Simulation and numerics, and Mathematical statistical data analysis.\n* A student has to select one specialization area as major field of study in which modules of in total 30 ECTS have to be completed.\n* All other specialization areas form the minor field of study in which modules of in total 20 ECTS have to be completed.\n* There are three core modules of in total 15 ECTS that are mandatory for all students of this degree program.\n* Technical qualification modules of in total 5 ECTS are also required.\n* Every student has to complete modules of in total 15 ECTS from the following application subjects: Artificial intelligence in biomedical imaging, Chemistry, Digital humanities, Geography, Geosciences, International information systems, Material Science, Medical data science, Multimedia Engineering, and Physics.\n* The degree program is finalized by a Master’s seminar (5 ECTS) that should lead to writing a Master’s thesis (30 ECTS) in the field of Data Science.\n\nThis information is based on the provided documents, specifically the ones with IDs 'f08db61f-24e4-4b07-b4bb-ec7fa9084de6' and '904cd6d2-9113-4ced-b68d-3d8b4b820c7a'.",
 'While German skills on a B1 level are highly recommended for the M.Sc. Data Science program at FAU Erlangen-Nuremberg, they are not strictly necessary, as the program is taught in English.',
 'The duration of the B.Sc. Data Science degree program at FAU Erlangen is 6 semesters.',
 'The teaching language of the B.Sc. Data Science at FAU Erlangen is completely in German.',
 'The Bachelor\'s degree program "Data Science" can be divided into the following consecutive levels:\n\n1.  The first year of study: Students learn the basics of computer science and mathematics.\n2.  The second year of study: Students learn the basics of data science, such as data analysis, machine learning, and data visualization.\n3.  The third year of study: Students learn advanced topics in data science, such as deep learning, natural language processing, and data mining.\n4.  The sixth semester: Students work on a bachelor\'s thesis project, where they apply the knowledge and skills they have learned to a real-world problem.',
 "The admission requirements for the B.Sc. Data Science program at FAU Erlangen-Nürnberg are as follows:\n\n1. No Admissions Restrictions: There are no specific admission restrictions for the B.Sc. Data Science program.\n2. Language skills: Very good German language skills are generally required for enrollment in the B.Sc. Data Science program. International students can find more detailed information on accepted language certificates at https://www.fau.de/education/international/aus-dem-ausland-an-die-fau/bewerbung-und-einschreibung-fuer-internationale-bewerberinnen-und-bewerber/deutschkenntnisse-und-sprachzertifikate/.\n3. General qualification for university entrance (Abitur): There are other access options for studying at FAU in addition to the general qualification for university entrance (Abitur).\n\nIt's also worth noting that the application deadline for the winter semester for international applicants is July 15th, and applications must be submitted via the campus management portal campo.fau.de."],

    'ground_truth': Ground_truth
}

# %%
dataset = Dataset.from_dict(data_samples)
score = evaluate(dataset,metrics=[answer_correctness])
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/42 [00:00<?, ?it/s]
#                                              question  \
# 0   Will the language of instruction of my Bachelo...
# 1   Is an APS certificate mandatory for Indian stu...
# 2   How long does it typically take to receive a d...
# 3   Am I eligible to apply for the study course pr...
# 4   Can I apply for the study course program with ...
# 5   What could be the reasons for receiving a reje...
# 6   Is it possible to defer my admission to a futu...
# 7   Where can I find accommodation while studying ...
# 8   Can I switch my major subject after being admi...
# 9   Is it allowed to combine modules from differen...
# 10  How can I transfer ECTS credits from one modul...
# 11  Can modules from my major subject count toward...
# 12  Can my werkstudent experience be used to earn ...
# 13  Can I participate in an examination without pr...
# 14  How do I register for a module’s examination i...
# ...

# %%
print(sum(score.to_pandas()["answer_correctness"]) / len(score.to_pandas()["answer_correctness"]))
# Out:
# 0.84179013024055
